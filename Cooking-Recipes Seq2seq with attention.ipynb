# %% [markdown]
# #### Import Libraries

# %%
# --- System & Utilities ---
import os                    # File and directory operations
import re                    # Regular expressions for string cleaning
import string                # String operations
import ast                   # Safe evaluation of Python expressions
import random                # Random operations (shuffling, sampling)
import time                  # Time tracking for performance
from collections import Counter  # Count frequencies of tokens

# --- Data Handling ---
import pandas as pd          # DataFrames for structured data
import numpy as np           # Numerical operations and arrays

# --- Natural Language Processing (NLP) ---
import nltk
from nltk.tokenize import word_tokenize           # Tokenize sentences/words
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction
from nltk.translate.meteor_score import meteor_score
from nltk.corpus import stopwords, wordnet        # Common stopwords and WordNet
from nltk.stem import WordNetLemmatizer           # Lemmatization for word normalization
from bert_score import score as bert_score        # Semantic similarity metric

# --- Deep Learning with PyTorch ---
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from torch.nn.utils.rnn import pad_sequence

# --- Visualization & Progress Tracking ---
import matplotlib.pyplot as plt                   # Plotting graphs
from tqdm import tqdm                              # Progress bar for loops

# --- Word Embeddings ---
from gensim.models import KeyedVectors            # Load pretrained word vectors

# --- Memory Management ---
import gc                                          # Garbage collection to manage RAM

# --- Optimization ---
import torch.optim as optim                       # Optimizers (e.g., Adam, SGD)

# %% [markdown]
# #### Set up the device

# %%
# --- Device Configuration ---
# Automatically select the best available device: MPS (Apple), CUDA (GPU), or CPU
if torch.backends.mps.is_available():
    device = torch.device('mps')
elif torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')

print("✅ Using device:", device)
# Out:
# Using device: mps

# %% [markdown]
# #### Special Tokens and Hyperparameters

# %%
# --- Special Tokens & Model Hyperparameters ---
# Define tokens for padding, start/end of sequence, and unknown words
PAD_TOKEN = "<pad>"
SOS_TOKEN = "<sos>"
EOS_TOKEN = "<eos>"
UNK_TOKEN = "<unk>"
SPECIAL_TOKENS = [PAD_TOKEN, SOS_TOKEN, EOS_TOKEN, UNK_TOKEN]

# Set model hyperparameters and data preprocessing constants
MAX_INGREDIENT_LEN = 20     # Max number of input tokens
MAX_RECIPE_LEN = 60         # Max number of output tokens
BATCH_SIZE = 64             # Training batch size
EMB_DIM = 64                # Word embedding dimension
HIDDEN_DIM = 256            # RNN hidden state dimension
TEACHER_FORCING_RATIO = 0.8 # Probability of using teacher forcing during training
num_iters = 10000           # Total training iterations
print_every = 50            # Frequency of logging training loss
plot_every = 50             # Frequency of computing validation loss and plotting

# %% [markdown]
# #### Data Processing

# %%
# Load your CSVs
train_df = pd.read_csv('/Users/myatpwintphyu/Desktop/Monash/2025 S1/NLP/Assignment_2/Cooking_Dataset/train.csv')
dev_df = pd.read_csv('/Users/myatpwintphyu/Desktop/Monash/2025 S1/NLP/Assignment_2/Cooking_Dataset/dev.csv')
test_df = pd.read_csv('/Users/myatpwintphyu/Desktop/Monash/2025 S1/NLP/Assignment_2/Cooking_Dataset/test.csv')

# %%
# --- NLP Preprocessing Utilities ---
lemmatizer = WordNetLemmatizer()                        # Word lemmatizer for reducing words to base form
stop_words = set(stopwords.words('english'))            # English stopwords to remove from text

# %%
# --- Text Cleaning and Formatting Functions ---
def preprocess_text(text):
    """
    Cleans and tokenizes a text string by lowercasing, removing non-alphabetic characters,
    removing stopwords, and applying lemmatization.
    """
    words = re.findall(r'\b[a-zA-Z]+\b', str(text).lower())
    words = [lemmatizer.lemmatize(w) for w in words if w not in stop_words]
    return words if words else ["unknown"]

def preprocess_ingredients_column(df):
    """Adds 'input_tokens' column by preprocessing the 'Ingredients' field."""
    df['input_tokens'] = df['Ingredients'].apply(preprocess_text)
    return df

def preprocess_recipes_column(df):
    """Adds 'output_tokens' column by preprocessing the 'Recipe' field."""
    df['output_tokens'] = df['Recipe'].apply(preprocess_text)
    return df

def format_input_prompt(tokens):
    """Formats ingredient tokens as a prompt string for generation."""
    return f"Generate recipe for: {', '.join(tokens)}"

def format_target_text(row):
    """Formats a row into a readable multi-line recipe string."""
    title = row['Title'] if 'Title' in row else 'Generated Recipe'
    ingredients = ', '.join(row['input_tokens'])
    instructions = ', '.join(row['output_tokens'])
    return f"Title: {title}\n\nIngredients:\n{ingredients}\nInstructions:\n{instructions}"

def build_vocab(token_lists):
    """
    Builds vocabulary from token lists and assigns unique index to each token.
    Includes special tokens.
    """
    vocab = {PAD_TOKEN: 0, SOS_TOKEN: 1, EOS_TOKEN: 2, UNK_TOKEN: 3}
    counter = Counter(token for tokens in token_lists for token in tokens)
    for token in counter:
        if token not in vocab:
            vocab[token] = len(vocab)
    return vocab

# %%
# --- Apply Preprocessing to Dataset Splits ---
# Tokenize and clean text fields for each split (train/dev/test)
train_df = preprocess_ingredients_column(train_df)
train_df = preprocess_recipes_column(train_df)

dev_df = preprocess_ingredients_column(dev_df)
dev_df = preprocess_recipes_column(dev_df)

test_df = preprocess_ingredients_column(test_df)
test_df = preprocess_recipes_column(test_df)

# %%
# --- Generate Input Prompts for Model ---
# Converts token lists into natural language prompts
train_df['input_prompt'] = train_df['input_tokens'].apply(format_input_prompt)
dev_df['input_prompt'] = dev_df['input_tokens'].apply(format_input_prompt)
test_df['input_prompt'] = test_df['input_tokens'].apply(format_input_prompt)

# %%
# --- Generate Readable Target Texts ---
# Combine title, ingredients, and instructions into formatted strings
train_df['target_text'] = train_df.apply(format_target_text, axis=1)
dev_df['target_text'] = dev_df.apply(format_target_text, axis=1)
test_df['target_text'] = test_df.apply(format_target_text, axis=1)

# %%
# --- Build Vocabularies ---
# Construct token-to-index mappings from training data
input_vocab = build_vocab(train_df['input_tokens'])
output_vocab = build_vocab(train_df['output_tokens'])

# Create reverse index-to-token dictionaries for decoding
input_idx2word = {i: w for w, i in input_vocab.items()}
output_idx2word = {i: w for w, i in output_vocab.items()}

# %%
def encode_text(tokens, vocab, max_len, is_target=False):
    """
    Encodes a list of tokens into a fixed-length list of token IDs using a vocabulary.

    Args:
        tokens: List of tokens (strings) to encode.
        vocab: Dictionary mapping tokens to indices.
        max_len: Maximum allowed length of the output sequence.
        is_target: If True, adds <sos> at the start and <eos> at the end.

    Returns:
        A list of token IDs (integers), padded or truncated to max_len.
    """
    encoded = []  # Initialize the list of token IDs

    if is_target:
        # Add <sos> token at the beginning if it's a target sequence
        encoded.append(vocab[SOS_TOKEN])
    
    for tok in tokens:
        # Convert each token to its corresponding index in the vocab
        # Use <unk> token index if token is not found
        encoded.append(vocab.get(tok, vocab[UNK_TOKEN]))

    if is_target:
        # Add <eos> token at the end if it's a target sequence
        encoded.append(vocab[EOS_TOKEN])

    # Ensure the sequence is exactly max_len in length
    if len(encoded) > max_len:
        # Truncate if too long
        encoded = encoded[:max_len]
    else:
        # Pad with <pad> tokens if too short
        encoded += [vocab[PAD_TOKEN]] * (max_len - len(encoded))

    return encoded  # Return the fixed-length list of token indices

# %%
class CookingDataset(Dataset):
    def __init__(self, df, input_vocab, output_vocab):
        """
        Args:
            df (DataFrame): The dataset containing tokenized ingredients and recipes.
            input_vocab (dict): Vocabulary mapping for input tokens (ingredients).
            output_vocab (dict): Vocabulary mapping for output tokens (recipes).
        """
        self.df = df
        self.input_vocab = input_vocab
        self.output_vocab = output_vocab

    def __len__(self):
        # Return the number of samples (rows) in the DataFrame
        return len(self.df)

    def __getitem__(self, idx):
        # Get token lists from the DataFrame at the given index
        src_tokens = self.df.iloc[idx]['input_tokens']   # Ingredients
        trg_tokens = self.df.iloc[idx]['output_tokens']  # Recipe steps

        # Encode the tokens using the vocabularies
        src_encoded = encode_text(src_tokens, self.input_vocab, MAX_INGREDIENT_LEN)
        trg_encoded = encode_text(trg_tokens, self.output_vocab, MAX_RECIPE_LEN, is_target=True)

        # Return as PyTorch tensors
        return torch.tensor(src_encoded), torch.tensor(trg_encoded)

# %%
def collate_fn(batch):
    """
    Custom collate function for DataLoader to pad sequences in a batch.

    Args:
        batch: A list of (input_tensor, target_tensor) tuples from the dataset.

    Returns:
        src_padded: Padded input tensor of shape (batch_size, max_input_len).
        trg_padded: Padded target tensor of shape (batch_size, max_target_len).
    """
    # Unpack the batch into two lists: inputs and targets
    src_batch, trg_batch = zip(*batch)

    # Pad input sequences to the length of the longest in the batch
    # batch_first=True -> shape will be (batch_size, seq_len)
    src_padded = pad_sequence(
        src_batch, batch_first=True, padding_value=input_vocab[PAD_TOKEN]
    )

    # Pad target sequences similarly
    trg_padded = pad_sequence(
        trg_batch, batch_first=True, padding_value=output_vocab[PAD_TOKEN]
    )

    # Return padded input and target batches
    return src_padded, trg_padded

# %%
train_dataset = CookingDataset(train_df, input_vocab, output_vocab)
dev_dataset = CookingDataset(dev_df, input_vocab, output_vocab)
test_dataset = CookingDataset(test_df, input_vocab, output_vocab)

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, collate_fn=collate_fn)
dev_loader = DataLoader(dev_dataset, batch_size=1, shuffle=False, collate_fn=collate_fn)
test_loader = DataLoader(test_dataset, batch_size=1, shuffle=False, collate_fn=collate_fn)

# %% [markdown]
# #### Epoch Time Calculation

# %%
# Helper function to format time nicely
def epoch_time(start_time, end_time):
    """
    Calculates elapsed time between two time points and formats it into minutes and seconds.

    Args:
        start_time: Float timestamp at the start (e.g., from time.time()).
        end_time: Float timestamp at the end.

    Returns:
        A tuple (minutes, seconds) representing the duration.
    """
    elapsed_time = end_time - start_time
    minutes = int(elapsed_time / 60)
    seconds = int(elapsed_time - (minutes * 60))
    return minutes, seconds

# %% [markdown]
# #### Evaluating Matrix

# %%
#This line creates a smoothing function for the BLEU score calculation using NLTK’s SmoothingFunction.
smoothie = SmoothingFunction().method4

# %%
def evaluate_model(model, data_loader, input_vocab, output_vocab, device, model_name="Seq2Seq-RNN"):
    """
    Evaluates a trained Seq2Seq model using BLEU, METEOR, and BERTScore.

    Args:
        model: The trained sequence-to-sequence model.
        data_loader: A DataLoader for the validation or test set.
        input_vocab: Vocabulary mapping for input tokens (not used in this function).
        output_vocab: Vocabulary mapping for output tokens (used for decoding).
        device: PyTorch device (e.g., 'cuda' or 'cpu').
        model_name: A string label for the model (used in the results dictionary).

    Returns:
        A dictionary containing average BLEU, METEOR, and BERTScore values for the dataset.
    """
    # Set the model to evaluation mode (disables dropout, etc.)
    model.eval()

    # Initialize lists to store evaluation metrics and text outputs
    bleu_scores = []
    meteor_scores = []
    predictions = []
    references = []

    # Create a reverse mapping from index to word for decoding output tokens
    output_idx2word = {i: w for w, i in output_vocab.items()}

    # Disable gradient calculation during evaluation
    with torch.no_grad():
        # Loop through batches from the validation/test DataLoader
        for src_batch, trg_batch in tqdm(data_loader, desc="Evaluating"):
            # Move batches to the correct device (CPU or GPU)
            src_batch = src_batch.to(device)
            trg_batch = trg_batch.to(device)

            # Get model predictions without teacher forcing
            output = model(src_batch, trg_batch, teacher_forcing_ratio=0.0)
            
            # Get the most likely token index at each time step
            # Shape: (batch_size, seq_len)
            output_ids = output.argmax(2)

            # Loop through each prediction-reference pair in the batch
            for pred_seq, true_seq in zip(output_ids, trg_batch):
                # Convert predicted token IDs to words, removing special tokens
                pred_tokens = [
                    output_idx2word.get(idx.item(), UNK_TOKEN)
                    for idx in pred_seq
                    if idx.item() not in [output_vocab[PAD_TOKEN], output_vocab[SOS_TOKEN], output_vocab[EOS_TOKEN]]
                ]

                true_tokens = [
                    output_idx2word.get(idx.item(), UNK_TOKEN)
                    for idx in true_seq
                    if idx.item() not in [output_vocab[PAD_TOKEN], output_vocab[SOS_TOKEN], output_vocab[EOS_TOKEN]]
                ]

                # Store string versions for corpus-level evaluation later
                predictions.append(" ".join(pred_tokens))
                references.append(" ".join(true_tokens))

                # Compute individual BLEU and METEOR scores for this sample
                bleu = sentence_bleu([true_tokens], pred_tokens, smoothing_function=smoothie)
                meteor = meteor_score([true_tokens], pred_tokens)

                bleu_scores.append(bleu)
                meteor_scores.append(meteor)

    # Compute BERTScore once for the entire corpus
    try:
        P, R, F1 = bert_score(predictions, references, lang="en", verbose=False)
        bert_f1 = F1.mean().item()
    except Exception as e:
        print(f"⚠️ BERTScore skipped due to error: {e}")
        bert_f1 = None

    # Compute average scores across all samples
    results = {
        "Model": model_name,
        "BLEU": sum(bleu_scores) / len(bleu_scores),
        "METEOR": sum(meteor_scores) / len(meteor_scores),
        "BERTScore": bert_f1 if bert_f1 is not None else "Unavailable"
    }

    return results

# %% [markdown]
# #### Evaluation loss

# %%
def evaluate_loss(model, val_loader, criterion, output_vocab, device):
    """
    Computes the average loss of a trained model on a validation dataset.

    Args:
        model: Trained Seq2Seq model.
        val_loader: DataLoader for the validation set.
        criterion: Loss function (e.g., nn.CrossEntropyLoss).
        output_vocab: Target vocabulary dictionary (not used directly here).
        device: PyTorch device (e.g., 'cuda' or 'cpu').

    Returns:
        Average validation loss across all batches.
    """
    model.eval()
    val_loss = 0

    with torch.no_grad():
        for src_batch, trg_batch in val_loader:
            src_batch = src_batch.to(device)
            trg_batch = trg_batch.to(device)

            output = model(src_batch, trg_batch, teacher_forcing_ratio=0.0)

            output_dim = output.shape[-1]
            output = output[:, 1:].reshape(-1, output_dim)
            target = trg_batch[:, 1:].reshape(-1)

            loss = criterion(output, target)
            val_loss += loss.item()

    return val_loss / len(val_loader)

# %% [markdown]
# #### Training Loop for Model

# %%
def train_model(model, train_loader, val_loader, optimizer, criterion, output_vocab, device,
                num_iters, print_every, plot_every, teacher_forcing_ratio=0.5, 
                log_filename="training_log.csv", plot_title="Training and Validation Loss"):
    """
    Trains a Seq2Seq model using random batches from the training data.
    Also tracks validation loss and logs progress over time.
    """
    
    import time
    from tqdm import tqdm

    model.train()  # Set model to training mode
    train_losses = []
    val_losses = []
    print_loss_total = 0  # Running total for printing
    plot_loss_total = 0   # Running total for plotting
    first_val_loss = None
    start_time = time.time()

    # Cache all training batches to randomly sample from them
    train_batches = list(train_loader)

    for iteration in range(1, num_iters + 1):
        # === Randomly sample a batch from training set ===
        input_batch, target_batch = random.choice(train_batches)
        input_batch = input_batch.to(device)
        target_batch = target_batch.to(device)

        model.train()
        optimizer.zero_grad()  # Reset gradients

        # === Forward pass ===
        output = model(input_batch, target_batch, teacher_forcing_ratio=teacher_forcing_ratio)

        # === Reshape output and target for loss computation ===
        output_dim = output.shape[-1]
        output = output[:, 1:].reshape(-1, output_dim)      # Skip <sos>
        target = target_batch[:, 1:].reshape(-1)

        # === Compute loss and backpropagation ===
        loss = criterion(output, target)
        loss.backward()
        optimizer.step()

        loss_value = loss.item()
        print_loss_total += loss_value
        plot_loss_total += loss_value

        # === Print training progress every 'print_every' iterations ===
        if iteration % print_every == 0:
            avg_loss = print_loss_total / print_every
            print_loss_total = 0
            elapsed = time.time() - start_time
            print(f"[Iter {iteration:05d}] ⏱ Time: {elapsed:.1f}s | Avg Train Loss: {avg_loss:.4f}")

        # === Validate and track performance every 'plot_every' iterations ===
        if iteration % plot_every == 0:
            val_loss_total = 0
            model.eval()  # Set model to evaluation mode (e.g., disable dropout)
            with torch.no_grad():  # Disable gradient tracking for validation
                for val_input, val_target in val_loader:
                    val_input = val_input.to(device)
                    val_target = val_target.to(device)

                    # In validation, use greedy decoding (no teacher forcing)
                    val_output = model(val_input, val_target, teacher_forcing_ratio=0.0)
                    val_output = val_output[:, 1:].reshape(-1, output_dim)
                    val_target = val_target[:, 1:].reshape(-1)
                    val_loss = criterion(val_output, val_target)
                    val_loss_total += val_loss.item()

            # Compute and store average validation loss
            avg_val_loss = val_loss_total / len(val_loader)
            train_losses.append(plot_loss_total / plot_every)
            val_losses.append(avg_val_loss)
            print(f"📉 Iter {iteration}: Val Loss = {avg_val_loss:.4f}")
            plot_loss_total = 0

    # === Save training and validation loss log to CSV ===
    log_data = {
        "Iteration": list(range(plot_every, plot_every * len(train_losses) + 1, plot_every)),
        "Training Loss": train_losses,
        "Validation Loss": val_losses
    }
    log_df = pd.DataFrame(log_data)
    log_df.to_csv(log_filename, index=False)
    print(f"📁 Training log saved to {log_filename}")

    # === Plot training vs. validation loss ===
    plt.figure(figsize=(8, 6))
    plt.plot(log_data["Iteration"], train_losses, label='Training Loss')
    plt.plot(log_data["Iteration"], val_losses, label='Validation Loss')
    plt.xlabel("Iteration")
    plt.ylabel("Loss")
    plt.title(plot_title)
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# #### Generating the Test Result

# %%
def generate_recipe(model, src_tensor, trg_vocab, device, max_len=MAX_RECIPE_LEN, use_attention=False):
    """
    Generates a recipe from a single input using either attention-based or vanilla seq2seq.

    Args:
        model: full seq2seq model or tuple (encoder, decoder)
        src_tensor: tensor of shape (src_len,)
        trg_vocab: target vocabulary (word to index)
        device: torch device (cpu/cuda)
        max_len: max length of the generated recipe
        use_attention: set to True if using (encoder, decoder) attention-style models

    Returns:
        String of generated recipe text.
    """
    model.eval()
    trg_vocab_inv = {i: w for w, i in trg_vocab.items()}

    with torch.no_grad():
        # Add batch dimension: (1, src_len)
        src_tensor = src_tensor.unsqueeze(0).to(device)

        if use_attention:
            # Expecting (encoder, decoder) as a tuple
            encoder, decoder = model
            encoder_outputs, hidden = encoder(src_tensor)

            input_token = torch.tensor([trg_vocab[SOS_TOKEN]], device=device)
            result = []

            for _ in range(max_len):
                output, hidden, _ = decoder(input_token, hidden, encoder_outputs)
                top1 = output.argmax(1).item()

                if top1 == trg_vocab[EOS_TOKEN]:
                    break
                result.append(trg_vocab_inv.get(top1, UNK_TOKEN))
                input_token = torch.tensor([top1], device=device)

        else:
            # Expecting model to be Seq2Seq class with internal encoder+decoder
            dummy_trg = torch.zeros((1, max_len), dtype=torch.long, device=device)
            output = model(src_tensor, dummy_trg, teacher_forcing_ratio=0.0)
            pred_ids = output.argmax(2).squeeze(0).tolist()

            result = []
            for idx in pred_ids:
                token = trg_vocab_inv.get(idx, UNK_TOKEN)
                if token == EOS_TOKEN:
                    break
                if token not in [PAD_TOKEN, SOS_TOKEN]:
                    result.append(token)

    return " ".join(result)

# %% [markdown]
# ### Baseline 2 Sequence-to-Sequence model with attention

# %% [markdown]
# #### Model

# %%
class EncoderRNN(nn.Module):
    """
        RNN-based encoder for a sequence-to-sequence model.

        This module takes an input sequence of token indices, embeds them, and passes the
        embeddings through a RNN to produce hidden state(s) used by the decoder.

        Args:
            input_vocab_size: Size of the input vocabulary.
            emb_dim: Dimensionality of the token embeddings.
            hidden_dim: Dimensionality of the RNN hidden state.

        Methods:
            forward(src): Encodes an input tensor and returns RNN outputs and final hidden state.
            initHidden(): Initializes a zero hidden state tensor.
    """
    def __init__(self, input_vocab_size, emb_dim, hidden_dim):
        super(EncoderRNN, self).__init__()

        # Embedding layer to convert token indices to dense vectors
        self.embedding = nn.Embedding(input_vocab_size, emb_dim)

        # RNN layer to process the sequence of embeddings
        self.rnn = nn.RNN(emb_dim, hidden_dim, batch_first=True)

        # Dropout layer for regularization (helps prevent overfitting)
        self.dropout = nn.Dropout(0.5)

        # Store the hidden state dimension
        self.hidden_size = hidden_dim

    def forward(self, src):
        # src: input sequence tensor of shape (batch_size, seq_len)

        embedded = self.embedding(src)          # Convert tokens to embeddings: (batch_size, seq_len, emb_dim)
        output, hidden = self.rnn(embedded)     # Pass through RNN: output (batch, seq_len, hidden_dim), hidden (1, batch, hidden_dim)
        output = self.dropout(output)           # Apply dropout to the RNN output

        return output, hidden                   # Return both the full sequence output and final hidden state

    def initHidden(self):
        # Create initial hidden state filled with zeros (for single batch/time)
        return torch.zeros(1, 1, self.hidden_size, device=device)

# %%
class AttentionDecoderRNN(nn.Module):
    """
        RNN-based decoder with additive attention mechanism for sequence-to-sequence models.

        This decoder uses attention to focus on different parts of the encoder's output
        at each decoding step, enhancing the model's ability to handle long or complex sequences.

        Args:
            output_dim: Size of the output vocabulary.
            emb_dim: Dimensionality of token embeddings.
            hidden_dim: Dimensionality of the RNN hidden state.

        Methods:
            forward(input_token, hidden, encoder_outputs):
                Performs a single decoding step with attention.
                Returns the predicted token distribution, updated hidden state, and attention weights.
    """
    def __init__(self, output_dim, emb_dim, hidden_dim):
        super().__init__()

        # Embedding layer: converts token indices to dense vectors
        self.embedding = nn.Embedding(output_dim, emb_dim)

        # Attention layer: takes [decoder_hidden + embedded_input] → attention weights
        self.attn = nn.Linear(hidden_dim + emb_dim, MAX_INGREDIENT_LEN)

        # Combines context vector (from attention) and embedded input
        self.attn_combine = nn.Linear(hidden_dim + emb_dim, hidden_dim)

        # Dropout for regularization
        self.dropout = nn.Dropout(0.3)

        # RNN layer: standard recurrent unit
        self.rnn = nn.RNN(hidden_dim, hidden_dim, batch_first=True)

        # Final output layer to project RNN output to vocabulary dimension
        self.fc_out = nn.Linear(hidden_dim, output_dim)

    def forward(self, input_token, hidden, encoder_outputs):
        """
        Args:
            input_token: current input token, shape (batch,)
            hidden: previous hidden state from decoder, shape (1, batch, hidden_dim)
            encoder_outputs: all encoder outputs, shape (batch, seq_len, hidden_dim)
        
        Returns:
            prediction: output token probabilities, shape (batch, vocab_size)
            hidden: updated decoder hidden state
            attn_weights: attention weights over encoder input, shape (batch, seq_len)
        """

        # Embed the input token and add time dimension: (batch, 1, emb_dim)
        embedded = self.embedding(input_token).unsqueeze(1)
        embedded = self.dropout(embedded)

        # Concatenate embedded input and previous hidden state for attention computation
        # Shape: (batch, emb_dim + hidden_dim)
        attn_input = torch.cat((embedded.squeeze(1), hidden.squeeze(0)), dim=1)

        # Compute attention weights: (batch, seq_len), softmax ensures they sum to 1
        attn_weights = torch.softmax(self.attn(attn_input), dim=1)

        # Apply attention weights to encoder outputs to get the context vector
        # Shape: (batch, 1, hidden_dim)
        attn_applied = torch.bmm(attn_weights.unsqueeze(1), encoder_outputs)

        # Concatenate embedded input and context, then combine and apply ReLU
        # Shape before: (batch, 1, emb_dim + hidden_dim) → after: (batch, 1, hidden_dim)
        rnn_input = torch.cat((embedded, attn_applied), dim=2)
        rnn_input = self.attn_combine(rnn_input).relu()

        # Run RNN with the combined context and input
        output, hidden = self.rnn(rnn_input, hidden)

        # Final prediction from the RNN output: shape (batch, vocab_size)
        prediction = self.fc_out(output.squeeze(1))

        return prediction, hidden, attn_weights

# %%
class Seq2SeqAttentionModel(nn.Module):
    """
        Sequence-to-sequence model with attention mechanism using RNN-based encoder and decoder.

        This model enhances the standard Seq2Seq architecture by applying attention at each
        decoding step, allowing the decoder to focus on relevant parts of the input sequence.

        Args:
            encoder: Encoder module that outputs hidden states for all input tokens.
            decoder: Attention-based decoder module (e.g., AttentionDecoderRNN).
            device: PyTorch device (e.g., 'cuda' or 'cpu') for model computation.

        Methods:
            forward(src, trg, teacher_forcing_ratio):
                Runs the model on a batch of input and target sequences.
                Returns the predicted token distributions over the output vocabulary.
    """

    def __init__(self, encoder, decoder, device):
        super(Seq2SeqAttentionModel, self).__init__()

        # Store the encoder and decoder (with attention)
        self.encoder = encoder
        self.decoder = decoder

        # Device (CPU or GPU) where model will run
        self.device = device

    def forward(self, src, trg, teacher_forcing_ratio=0.5):
        """
        Forward pass for Seq2Seq model with attention.

        Args:
            src: input tensor of shape (batch, src_len)
            trg: target tensor of shape (batch, trg_len)
            teacher_forcing_ratio: probability to use actual target token instead of predicted one

        Returns:
            outputs: tensor of shape (batch, trg_len, vocab_size)
        """

        batch_size = src.size(0)                 # Number of sequences in the batch
        trg_len = trg.size(1)                    # Length of the target sequences
        vocab_size = self.decoder.fc_out.out_features  # Output vocabulary size

        # Placeholder tensor to store decoder outputs at each time step
        outputs = torch.zeros(batch_size, trg_len, vocab_size).to(self.device)

        # Pass the input sequence through the encoder
        encoder_outputs, hidden = self.encoder(src)

        # Initialize decoder with the <sos> token from target input
        input_token = trg[:, 0]  # Shape: (batch,)

        # Loop over each time step in the target sequence (starting from t=1)
        for t in range(1, trg_len):
            # Pass input token, previous hidden state, and encoder outputs to the decoder
            output, hidden, _ = self.decoder(input_token, hidden, encoder_outputs)

            # Store the decoder's prediction at current time step
            outputs[:, t] = output

            # Decide whether to use teacher forcing (ground truth) or model prediction
            teacher_force = torch.rand(1).item() < teacher_forcing_ratio

            # Get predicted token (argmax over vocab)
            top1 = output.argmax(1)

            # Next input is either actual token from target or predicted token
            input_token = trg[:, t] if teacher_force else top1

        # Return all decoder outputs for the batch
        return outputs

# %% [markdown]
# #### Training the Model

# %%
# === Instantiate attention-based decoder ===
# This decoder includes an attention mechanism to help the model focus on relevant parts of the input sequence
decoder_attention = AttentionDecoderRNN(
    output_dim=len(output_vocab),   # Size of the output vocabulary
    emb_dim=EMB_DIM,                # Embedding dimension
    hidden_dim=HIDDEN_DIM           # Hidden state dimension
).to(device)

encoder = EncoderRNN(input_vocab_size=len(input_vocab), emb_dim=EMB_DIM, hidden_dim=HIDDEN_DIM).to(device)

# === Instantiate Seq2Seq model with attention mechanism ===
# Combines the encoder with the attention-based decoder into a unified model
model_attention = Seq2SeqAttentionModel(
    encoder=encoder,               # Shared encoder from the baseline
    decoder=decoder_attention,     # Attention-enhanced decoder
    device=device                  # Move model to appropriate device (CPU/GPU)
).to(device)

# === Define optimizer and loss function ===
# Adam optimizer for training; loss ignores <pad> tokens in target sequences
optimizer_baseline2 = torch.optim.Adam(model_attention.parameters(), lr=0.00005, weight_decay=1e-5)
criterion = nn.CrossEntropyLoss(ignore_index=output_vocab[PAD_TOKEN])

# === Train the attention-based Seq2Seq model ===
# This uses the same training loop as the baseline but enables better alignment through attention
train_model(
    model=model_attention,
    train_loader=train_loader,
    val_loader=dev_loader,
    optimizer=optimizer_baseline2,
    criterion=criterion,
    output_vocab=output_vocab,
    device=device,
    num_iters=num_iters,
    print_every=print_every,
    plot_every=plot_every,
    teacher_forcing_ratio=TEACHER_FORCING_RATIO,  # Controls how often the true target is used during training
    log_filename="Sequence-to-Sequence model with attention.csv",
    plot_title="Sequence-to-Sequence model with attention"
)
# Out:
# [Iter 00050] ⏱ Time: 32.9s | Avg Train Loss: 9.0998
# 📉 Iter 50: Val Loss = 8.5502
# [Iter 00100] ⏱ Time: 92.9s | Avg Train Loss: 7.8641
# 📉 Iter 100: Val Loss = 7.1826
# [Iter 00150] ⏱ Time: 150.4s | Avg Train Loss: 6.8805
# 📉 Iter 150: Val Loss = 6.5326
# [Iter 00200] ⏱ Time: 211.3s | Avg Train Loss: 6.4436
# 📉 Iter 200: Val Loss = 6.2457
# [Iter 00250] ⏱ Time: 268.8s | Avg Train Loss: 6.2491
# 📉 Iter 250: Val Loss = 6.1163
# [Iter 00300] ⏱ Time: 324.9s | Avg Train Loss: 6.1493
# 📉 Iter 300: Val Loss = 6.0536
# [Iter 00350] ⏱ Time: 387.0s | Avg Train Loss: 6.1194
# 📉 Iter 350: Val Loss = 6.0202
# [Iter 00400] ⏱ Time: 447.4s | Avg Train Loss: 6.1051
# 📉 Iter 400: Val Loss = 5.9995
# [Iter 00450] ⏱ Time: 505.1s | Avg Train Loss: 6.0812
# 📉 Iter 450: Val Loss = 5.9825
# [Iter 00500] ⏱ Time: 571.8s | Avg Train Loss: 6.0647
# 📉 Iter 500: Val Loss = 5.9726
# [Iter 00550] ⏱ Time: 628.0s | Avg Train Loss: 6.0535
# 📉 Iter 550: Val Loss = 5.9643
# [Iter 00600] ⏱ Time: 689.0s | Avg Train Loss: 6.0435
# 📉 Iter 600: Val Loss = 5.9579
# [Iter 00650] ⏱ Time: 761.4s | Avg Train Loss: 6.0479
# 📉 Iter 650: Val Loss = 5.9531
# [Iter 00700] ⏱ Time: 825.6s | Avg Train Loss: 6.0269
# 📉 Iter 700: Val Loss = 5.9456
# [Iter 00750] ⏱ Time: 884.1s | Avg Train Loss: 6.0470
# 📉 Iter 750: Val Loss = 5.9431
# [Iter 00800] ⏱ Time: 949.0s | Avg Train Loss: 6.0339
# 📉 Iter 800: Val Loss = 5.9413
# [Iter 00850] ⏱ Time: 1005.7s | Avg Train Loss: 6.0430
# 📉 Iter 850: Val Loss = 5.9373
# [Iter 00900] ⏱ Time: 1066.8s | Avg Train Loss: 6.0121
# 📉 Iter 900: Val Loss = 5.9339
# [Iter 00950] ⏱ Time: 1128.4s | Avg Train Loss: 6.0171
# 📉 Iter 950: Val Loss = 5.9291
# [Iter 01000] ⏱ Time: 1185.0s | Avg Train Loss: 6.0280
# 📉 Iter 1000: Val Loss = 5.9274
# [Iter 01050] ⏱ Time: 1246.8s | Avg Train Loss: 6.0105
# 📉 Iter 1050: Val Loss = 5.9250
# [Iter 01100] ⏱ Time: 1308.8s | Avg Train Loss: 6.0326
# 📉 Iter 1100: Val Loss = 5.9228
# [Iter 01150] ⏱ Time: 1368.4s | Avg Train Loss: 6.0235
# 📉 Iter 1150: Val Loss = 5.9212
# [Iter 01200] ⏱ Time: 1433.7s | Avg Train Loss: 6.0135
# 📉 Iter 1200: Val Loss = 5.9184
# [Iter 01250] ⏱ Time: 1497.2s | Avg Train Loss: 6.0213
# 📉 Iter 1250: Val Loss = 5.9154
# [Iter 01300] ⏱ Time: 1557.2s | Avg Train Loss: 6.0297
# 📉 Iter 1300: Val Loss = 5.9148
# [Iter 01350] ⏱ Time: 1628.8s | Avg Train Loss: 6.0133
# 📉 Iter 1350: Val Loss = 5.9133
# [Iter 01400] ⏱ Time: 1689.6s | Avg Train Loss: 5.9873
# 📉 Iter 1400: Val Loss = 5.9113
# [Iter 01450] ⏱ Time: 1748.7s | Avg Train Loss: 6.0074
# 📉 Iter 1450: Val Loss = 5.9103
# [Iter 01500] ⏱ Time: 1814.5s | Avg Train Loss: 5.9976
# 📉 Iter 1500: Val Loss = 5.9078
# [Iter 01550] ⏱ Time: 1871.8s | Avg Train Loss: 6.0093
# 📉 Iter 1550: Val Loss = 5.9085
# [Iter 01600] ⏱ Time: 1933.2s | Avg Train Loss: 5.9987
# 📉 Iter 1600: Val Loss = 5.9061
# [Iter 01650] ⏱ Time: 1996.5s | Avg Train Loss: 6.0160
# 📉 Iter 1650: Val Loss = 5.9056
# [Iter 01700] ⏱ Time: 2054.4s | Avg Train Loss: 5.9785
# 📉 Iter 1700: Val Loss = 5.9028
# [Iter 01750] ⏱ Time: 2117.7s | Avg Train Loss: 5.9847
# 📉 Iter 1750: Val Loss = 5.9003
# [Iter 01800] ⏱ Time: 2178.3s | Avg Train Loss: 6.0044
# 📉 Iter 1800: Val Loss = 5.9003
# [Iter 01850] ⏱ Time: 2238.3s | Avg Train Loss: 5.9918
# 📉 Iter 1850: Val Loss = 5.8952
# [Iter 01900] ⏱ Time: 2302.8s | Avg Train Loss: 5.9989
# 📉 Iter 1900: Val Loss = 5.8959
# [Iter 01950] ⏱ Time: 2364.7s | Avg Train Loss: 5.9980
# 📉 Iter 1950: Val Loss = 5.8917
# [Iter 02000] ⏱ Time: 2454.0s | Avg Train Loss: 5.9841
# 📉 Iter 2000: Val Loss = 5.8900
# [Iter 02050] ⏱ Time: 2533.7s | Avg Train Loss: 5.9675
# 📉 Iter 2050: Val Loss = 5.8861
# [Iter 02100] ⏱ Time: 2697.6s | Avg Train Loss: 5.9726
# 📉 Iter 2100: Val Loss = 5.8859
# [Iter 02150] ⏱ Time: 2771.1s | Avg Train Loss: 5.9932
# 📉 Iter 2150: Val Loss = 5.8861
# [Iter 02200] ⏱ Time: 2834.3s | Avg Train Loss: 5.9861
# 📉 Iter 2200: Val Loss = 5.8846
# [Iter 02250] ⏱ Time: 2889.5s | Avg Train Loss: 5.9852
# 📉 Iter 2250: Val Loss = 5.8825
# [Iter 02300] ⏱ Time: 2948.4s | Avg Train Loss: 5.9727
# 📉 Iter 2300: Val Loss = 5.8832
# [Iter 02350] ⏱ Time: 3011.5s | Avg Train Loss: 5.9608
# 📉 Iter 2350: Val Loss = 5.8791
# [Iter 02400] ⏱ Time: 3066.1s | Avg Train Loss: 5.9957
# 📉 Iter 2400: Val Loss = 5.9053
# [Iter 02450] ⏱ Time: 3126.7s | Avg Train Loss: 5.9701
# 📉 Iter 2450: Val Loss = 5.9168
# [Iter 02500] ⏱ Time: 3191.7s | Avg Train Loss: 5.9543
# 📉 Iter 2500: Val Loss = 5.9375
# [Iter 02550] ⏱ Time: 3246.3s | Avg Train Loss: 5.9617
# 📉 Iter 2550: Val Loss = 5.9324
# [Iter 02600] ⏱ Time: 3308.4s | Avg Train Loss: 5.9510
# 📉 Iter 2600: Val Loss = 5.9375
# [Iter 02650] ⏱ Time: 3366.6s | Avg Train Loss: 5.9627
# 📉 Iter 2650: Val Loss = 5.9276
# [Iter 02700] ⏱ Time: 3423.8s | Avg Train Loss: 5.9598
# 📉 Iter 2700: Val Loss = 5.9389
# [Iter 02750] ⏱ Time: 3491.9s | Avg Train Loss: 5.9411
# 📉 Iter 2750: Val Loss = 5.9539
# [Iter 02800] ⏱ Time: 3549.6s | Avg Train Loss: 5.9495
# 📉 Iter 2800: Val Loss = 5.9387
# [Iter 02850] ⏱ Time: 3610.0s | Avg Train Loss: 5.9477
# 📉 Iter 2850: Val Loss = 5.9415
# [Iter 02900] ⏱ Time: 3677.9s | Avg Train Loss: 5.9417
# 📉 Iter 2900: Val Loss = 5.9463
# [Iter 02950] ⏱ Time: 3735.7s | Avg Train Loss: 5.9003
# 📉 Iter 2950: Val Loss = 5.9416
# [Iter 03000] ⏱ Time: 3794.2s | Avg Train Loss: 5.8905
# 📉 Iter 3000: Val Loss = 5.9151
# [Iter 03050] ⏱ Time: 3857.6s | Avg Train Loss: 5.9146
# 📉 Iter 3050: Val Loss = 5.9344
# [Iter 03100] ⏱ Time: 3915.7s | Avg Train Loss: 5.9017
# 📉 Iter 3100: Val Loss = 5.9279
# [Iter 03150] ⏱ Time: 3983.2s | Avg Train Loss: 5.9090
# 📉 Iter 3150: Val Loss = 5.9150
# [Iter 03200] ⏱ Time: 4042.5s | Avg Train Loss: 5.8697
# 📉 Iter 3200: Val Loss = 5.9227
# [Iter 03250] ⏱ Time: 4101.6s | Avg Train Loss: 5.8552
# 📉 Iter 3250: Val Loss = 5.9123
# [Iter 03300] ⏱ Time: 4169.5s | Avg Train Loss: 5.8899
# 📉 Iter 3300: Val Loss = 5.8983
# [Iter 03350] ⏱ Time: 4226.5s | Avg Train Loss: 5.8644
# 📉 Iter 3350: Val Loss = 5.8809
# [Iter 03400] ⏱ Time: 4281.5s | Avg Train Loss: 5.8389
# 📉 Iter 3400: Val Loss = 5.8792
# [Iter 03450] ⏱ Time: 4344.2s | Avg Train Loss: 5.8301
# 📉 Iter 3450: Val Loss = 5.8807
# [Iter 03500] ⏱ Time: 4398.0s | Avg Train Loss: 5.8118
# 📉 Iter 3500: Val Loss = 5.8647
# [Iter 03550] ⏱ Time: 4455.0s | Avg Train Loss: 5.8275
# 📉 Iter 3550: Val Loss = 5.8593
# [Iter 03600] ⏱ Time: 4515.4s | Avg Train Loss: 5.8016
# 📉 Iter 3600: Val Loss = 5.8588
# [Iter 03650] ⏱ Time: 4569.4s | Avg Train Loss: 5.8052
# 📉 Iter 3650: Val Loss = 5.8333
# [Iter 03700] ⏱ Time: 4628.5s | Avg Train Loss: 5.7921
# 📉 Iter 3700: Val Loss = 5.8400
# [Iter 03750] ⏱ Time: 4686.9s | Avg Train Loss: 5.7887
# 📉 Iter 3750: Val Loss = 5.8310
# [Iter 03800] ⏱ Time: 4740.5s | Avg Train Loss: 5.7829
# 📉 Iter 3800: Val Loss = 5.8265
# [Iter 03850] ⏱ Time: 4802.0s | Avg Train Loss: 5.7678
# 📉 Iter 3850: Val Loss = 5.8219
# [Iter 03900] ⏱ Time: 4857.4s | Avg Train Loss: 5.7634
# 📉 Iter 3900: Val Loss = 5.8153
# [Iter 03950] ⏱ Time: 4911.9s | Avg Train Loss: 5.7640
# 📉 Iter 3950: Val Loss = 5.8081
# [Iter 04000] ⏱ Time: 4974.6s | Avg Train Loss: 5.7639
# 📉 Iter 4000: Val Loss = 5.8261
# [Iter 04050] ⏱ Time: 5029.3s | Avg Train Loss: 5.7504
# 📉 Iter 4050: Val Loss = 5.8096
# [Iter 04100] ⏱ Time: 5087.3s | Avg Train Loss: 5.7305
# 📉 Iter 4100: Val Loss = 5.8154
# [Iter 04150] ⏱ Time: 5147.9s | Avg Train Loss: 5.7287
# 📉 Iter 4150: Val Loss = 5.8077
# [Iter 04200] ⏱ Time: 5201.7s | Avg Train Loss: 5.7164
# 📉 Iter 4200: Val Loss = 5.8071
# [Iter 04250] ⏱ Time: 5261.2s | Avg Train Loss: 5.7089
# 📉 Iter 4250: Val Loss = 5.8206
# [Iter 04300] ⏱ Time: 5319.0s | Avg Train Loss: 5.7227
# 📉 Iter 4300: Val Loss = 5.8051
# [Iter 04350] ⏱ Time: 5372.8s | Avg Train Loss: 5.6838
# 📉 Iter 4350: Val Loss = 5.8034
# [Iter 04400] ⏱ Time: 5434.3s | Avg Train Loss: 5.6860
# 📉 Iter 4400: Val Loss = 5.8007
# [Iter 04450] ⏱ Time: 5491.0s | Avg Train Loss: 5.6831
# 📉 Iter 4450: Val Loss = 5.8010
# [Iter 04500] ⏱ Time: 5545.2s | Avg Train Loss: 5.6732
# 📉 Iter 4500: Val Loss = 5.8013
# [Iter 04550] ⏱ Time: 5609.1s | Avg Train Loss: 5.6681
# 📉 Iter 4550: Val Loss = 5.8079
# [Iter 04600] ⏱ Time: 5663.6s | Avg Train Loss: 5.6453
# 📉 Iter 4600: Val Loss = 5.8070
# [Iter 04650] ⏱ Time: 5719.6s | Avg Train Loss: 5.6445
# 📉 Iter 4650: Val Loss = 5.8047
# [Iter 04700] ⏱ Time: 5782.1s | Avg Train Loss: 5.6563
# 📉 Iter 4700: Val Loss = 5.7895
# [Iter 04750] ⏱ Time: 5836.3s | Avg Train Loss: 5.6519
# 📉 Iter 4750: Val Loss = 5.7953
# [Iter 04800] ⏱ Time: 5894.3s | Avg Train Loss: 5.6519
# 📉 Iter 4800: Val Loss = 5.8052
# [Iter 04850] ⏱ Time: 5953.5s | Avg Train Loss: 5.6223
# 📉 Iter 4850: Val Loss = 5.8120
# [Iter 04900] ⏱ Time: 6008.6s | Avg Train Loss: 5.6130
# 📉 Iter 4900: Val Loss = 5.8056
# [Iter 04950] ⏱ Time: 6068.7s | Avg Train Loss: 5.6126
# 📉 Iter 4950: Val Loss = 5.8206
# [Iter 05000] ⏱ Time: 6126.3s | Avg Train Loss: 5.6117
# 📉 Iter 5000: Val Loss = 5.8120
# [Iter 05050] ⏱ Time: 6180.7s | Avg Train Loss: 5.6003
# 📉 Iter 5050: Val Loss = 5.8018
# [Iter 05100] ⏱ Time: 6242.9s | Avg Train Loss: 5.5890
# 📉 Iter 5100: Val Loss = 5.8080
# [Iter 05150] ⏱ Time: 6298.4s | Avg Train Loss: 5.6278
# 📉 Iter 5150: Val Loss = 5.8126
# [Iter 05200] ⏱ Time: 6353.3s | Avg Train Loss: 5.5801
# 📉 Iter 5200: Val Loss = 5.8089
# [Iter 05250] ⏱ Time: 6416.7s | Avg Train Loss: 5.5702
# 📉 Iter 5250: Val Loss = 5.8025
# [Iter 05300] ⏱ Time: 6471.4s | Avg Train Loss: 5.5654
# 📉 Iter 5300: Val Loss = 5.8132
# [Iter 05350] ⏱ Time: 6528.6s | Avg Train Loss: 5.5663
# 📉 Iter 5350: Val Loss = 5.8112
# [Iter 05400] ⏱ Time: 6588.9s | Avg Train Loss: 5.5478
# 📉 Iter 5400: Val Loss = 5.7922
# [Iter 05450] ⏱ Time: 6643.0s | Avg Train Loss: 5.5921
# 📉 Iter 5450: Val Loss = 5.7884
# [Iter 05500] ⏱ Time: 6701.2s | Avg Train Loss: 5.5591
# 📉 Iter 5500: Val Loss = 5.8048
# [Iter 05550] ⏱ Time: 6760.1s | Avg Train Loss: 5.5303
# 📉 Iter 5550: Val Loss = 5.8007
# [Iter 05600] ⏱ Time: 6814.2s | Avg Train Loss: 5.5421
# 📉 Iter 5600: Val Loss = 5.8173
# [Iter 05650] ⏱ Time: 6874.8s | Avg Train Loss: 5.5496
# 📉 Iter 5650: Val Loss = 5.8328
# [Iter 05700] ⏱ Time: 6932.9s | Avg Train Loss: 5.5269
# 📉 Iter 5700: Val Loss = 5.8046
# [Iter 05750] ⏱ Time: 6981.9s | Avg Train Loss: 5.5186
# 📉 Iter 5750: Val Loss = 5.8297
# [Iter 05800] ⏱ Time: 7030.5s | Avg Train Loss: 5.5343
# 📉 Iter 5800: Val Loss = 5.8250
# [Iter 05850] ⏱ Time: 7078.8s | Avg Train Loss: 5.5001
# 📉 Iter 5850: Val Loss = 5.8299
# [Iter 05900] ⏱ Time: 7125.2s | Avg Train Loss: 5.4989
# 📉 Iter 5900: Val Loss = 5.8237
# [Iter 05950] ⏱ Time: 7171.9s | Avg Train Loss: 5.5203
# 📉 Iter 5950: Val Loss = 5.8098
# [Iter 06000] ⏱ Time: 7218.6s | Avg Train Loss: 5.5108
# 📉 Iter 6000: Val Loss = 5.8166
# [Iter 06050] ⏱ Time: 7265.4s | Avg Train Loss: 5.5035
# 📉 Iter 6050: Val Loss = 5.8229
# [Iter 06100] ⏱ Time: 7312.0s | Avg Train Loss: 5.4706
# 📉 Iter 6100: Val Loss = 5.8011
# [Iter 06150] ⏱ Time: 7357.4s | Avg Train Loss: 5.4685
# 📉 Iter 6150: Val Loss = 5.8347
# [Iter 06200] ⏱ Time: 7402.8s | Avg Train Loss: 5.4897
# 📉 Iter 6200: Val Loss = 5.8254
# [Iter 06250] ⏱ Time: 7448.2s | Avg Train Loss: 5.4405
# 📉 Iter 6250: Val Loss = 5.8173
# [Iter 06300] ⏱ Time: 7493.9s | Avg Train Loss: 5.4847
# 📉 Iter 6300: Val Loss = 5.8237
# [Iter 06350] ⏱ Time: 7541.8s | Avg Train Loss: 5.4571
# 📉 Iter 6350: Val Loss = 5.8276
# [Iter 06400] ⏱ Time: 7589.9s | Avg Train Loss: 5.4643
# 📉 Iter 6400: Val Loss = 5.8225
# [Iter 06450] ⏱ Time: 7637.6s | Avg Train Loss: 5.4404
# 📉 Iter 6450: Val Loss = 5.8155
# [Iter 06500] ⏱ Time: 7687.2s | Avg Train Loss: 5.4394
# 📉 Iter 6500: Val Loss = 5.8426
# [Iter 06550] ⏱ Time: 7736.5s | Avg Train Loss: 5.4463
# 📉 Iter 6550: Val Loss = 5.8290
# [Iter 06600] ⏱ Time: 7786.7s | Avg Train Loss: 5.4390
# 📉 Iter 6600: Val Loss = 5.8255
# [Iter 06650] ⏱ Time: 7853.1s | Avg Train Loss: 5.4192
# 📉 Iter 6650: Val Loss = 5.8356
# [Iter 06700] ⏱ Time: 7905.4s | Avg Train Loss: 5.4135
# 📉 Iter 6700: Val Loss = 5.8116
# [Iter 06750] ⏱ Time: 7967.6s | Avg Train Loss: 5.4429
# 📉 Iter 6750: Val Loss = 5.8311
# [Iter 06800] ⏱ Time: 8022.1s | Avg Train Loss: 5.4179
# 📉 Iter 6800: Val Loss = 5.8364
# [Iter 06850] ⏱ Time: 8084.1s | Avg Train Loss: 5.4380
# 📉 Iter 6850: Val Loss = 5.8372
# [Iter 06900] ⏱ Time: 8144.3s | Avg Train Loss: 5.4060
# 📉 Iter 6900: Val Loss = 5.8291
# [Iter 06950] ⏱ Time: 8203.0s | Avg Train Loss: 5.3850
# 📉 Iter 6950: Val Loss = 5.8300
# [Iter 07000] ⏱ Time: 8267.7s | Avg Train Loss: 5.4012
# 📉 Iter 7000: Val Loss = 5.8242
# [Iter 07050] ⏱ Time: 8322.6s | Avg Train Loss: 5.3907
# 📉 Iter 7050: Val Loss = 5.8205
# [Iter 07100] ⏱ Time: 8387.8s | Avg Train Loss: 5.3906
# 📉 Iter 7100: Val Loss = 5.8151
# [Iter 07150] ⏱ Time: 8438.2s | Avg Train Loss: 5.3889
# 📉 Iter 7150: Val Loss = 5.8360
# [Iter 07200] ⏱ Time: 8502.0s | Avg Train Loss: 5.3964
# 📉 Iter 7200: Val Loss = 5.8318
# [Iter 07250] ⏱ Time: 8555.5s | Avg Train Loss: 5.3740
# 📉 Iter 7250: Val Loss = 5.8052
# [Iter 07300] ⏱ Time: 8617.6s | Avg Train Loss: 5.3600
# 📉 Iter 7300: Val Loss = 5.8302
# [Iter 07350] ⏱ Time: 8682.8s | Avg Train Loss: 5.3523
# 📉 Iter 7350: Val Loss = 5.8289
# [Iter 07400] ⏱ Time: 8749.6s | Avg Train Loss: 5.3370
# 📉 Iter 7400: Val Loss = 5.8350
# [Iter 07450] ⏱ Time: 8800.2s | Avg Train Loss: 5.3596
# 📉 Iter 7450: Val Loss = 5.8281
# [Iter 07500] ⏱ Time: 8865.3s | Avg Train Loss: 5.3315
# 📉 Iter 7500: Val Loss = 5.8083
# [Iter 07550] ⏱ Time: 8918.1s | Avg Train Loss: 5.3250
# 📉 Iter 7550: Val Loss = 5.8207
# [Iter 07600] ⏱ Time: 8981.0s | Avg Train Loss: 5.3418
# 📉 Iter 7600: Val Loss = 5.8147
# [Iter 07650] ⏱ Time: 9036.1s | Avg Train Loss: 5.3257
# 📉 Iter 7650: Val Loss = 5.8259
# [Iter 07700] ⏱ Time: 9096.9s | Avg Train Loss: 5.3321
# 📉 Iter 7700: Val Loss = 5.8346
# [Iter 07750] ⏱ Time: 9156.7s | Avg Train Loss: 5.3421
# 📉 Iter 7750: Val Loss = 5.7925
# [Iter 07800] ⏱ Time: 9215.0s | Avg Train Loss: 5.3276
# 📉 Iter 7800: Val Loss = 5.8361
# [Iter 07850] ⏱ Time: 9283.7s | Avg Train Loss: 5.3151
# 📉 Iter 7850: Val Loss = 5.8268
# [Iter 07900] ⏱ Time: 9341.4s | Avg Train Loss: 5.3336
# 📉 Iter 7900: Val Loss = 5.8213
# [Iter 07950] ⏱ Time: 9419.8s | Avg Train Loss: 5.3018
# 📉 Iter 7950: Val Loss = 5.8180
# [Iter 08000] ⏱ Time: 9475.0s | Avg Train Loss: 5.2780
# 📉 Iter 8000: Val Loss = 5.8256
# [Iter 08050] ⏱ Time: 9541.1s | Avg Train Loss: 5.3124
# 📉 Iter 8050: Val Loss = 5.8298
# [Iter 08100] ⏱ Time: 9598.5s | Avg Train Loss: 5.2750
# 📉 Iter 8100: Val Loss = 5.8055
# [Iter 08150] ⏱ Time: 9659.0s | Avg Train Loss: 5.2997
# 📉 Iter 8150: Val Loss = 5.8057
# [Iter 08200] ⏱ Time: 9706.8s | Avg Train Loss: 5.2864
# 📉 Iter 8200: Val Loss = 5.8091
# [Iter 08250] ⏱ Time: 9757.8s | Avg Train Loss: 5.2953
# 📉 Iter 8250: Val Loss = 5.8038
# [Iter 08300] ⏱ Time: 9806.4s | Avg Train Loss: 5.3060
# 📉 Iter 8300: Val Loss = 5.7997
# [Iter 08350] ⏱ Time: 9857.2s | Avg Train Loss: 5.2756
# 📉 Iter 8350: Val Loss = 5.8185
# [Iter 08400] ⏱ Time: 9907.5s | Avg Train Loss: 5.2687
# 📉 Iter 8400: Val Loss = 5.8199
# [Iter 08450] ⏱ Time: 9958.9s | Avg Train Loss: 5.2708
# 📉 Iter 8450: Val Loss = 5.8198
# [Iter 08500] ⏱ Time: 10008.3s | Avg Train Loss: 5.2501
# 📉 Iter 8500: Val Loss = 5.8313
# [Iter 08550] ⏱ Time: 10059.3s | Avg Train Loss: 5.2576
# 📉 Iter 8550: Val Loss = 5.8338
# [Iter 08600] ⏱ Time: 10108.3s | Avg Train Loss: 5.2507
# 📉 Iter 8600: Val Loss = 5.8023
# [Iter 08650] ⏱ Time: 10172.6s | Avg Train Loss: 5.2792
# 📉 Iter 8650: Val Loss = 5.8139
# [Iter 08700] ⏱ Time: 10226.9s | Avg Train Loss: 5.2702
# 📉 Iter 8700: Val Loss = 5.7926
# [Iter 08750] ⏱ Time: 10286.1s | Avg Train Loss: 5.2558
# 📉 Iter 8750: Val Loss = 5.8070
# [Iter 08800] ⏱ Time: 10344.9s | Avg Train Loss: 5.2166
# 📉 Iter 8800: Val Loss = 5.8072
# [Iter 08850] ⏱ Time: 10401.6s | Avg Train Loss: 5.2096
# 📉 Iter 8850: Val Loss = 5.8055
# [Iter 08900] ⏱ Time: 10465.1s | Avg Train Loss: 5.2149
# 📉 Iter 8900: Val Loss = 5.7884
# [Iter 08950] ⏱ Time: 10520.1s | Avg Train Loss: 5.2174
# 📉 Iter 8950: Val Loss = 5.8012
# [Iter 09000] ⏱ Time: 10575.8s | Avg Train Loss: 5.2369
# 📉 Iter 9000: Val Loss = 5.8079
# [Iter 09050] ⏱ Time: 10637.0s | Avg Train Loss: 5.2016
# 📉 Iter 9050: Val Loss = 5.8057
# [Iter 09100] ⏱ Time: 10690.9s | Avg Train Loss: 5.2067
# 📉 Iter 9100: Val Loss = 5.8177
# [Iter 09150] ⏱ Time: 10751.6s | Avg Train Loss: 5.2382
# 📉 Iter 9150: Val Loss = 5.7931
# [Iter 09200] ⏱ Time: 10809.9s | Avg Train Loss: 5.2208
# 📉 Iter 9200: Val Loss = 5.8260
# [Iter 09250] ⏱ Time: 10864.1s | Avg Train Loss: 5.2156
# 📉 Iter 9250: Val Loss = 5.7871
# [Iter 09300] ⏱ Time: 10927.6s | Avg Train Loss: 5.2010
# 📉 Iter 9300: Val Loss = 5.8135
# [Iter 09350] ⏱ Time: 10984.9s | Avg Train Loss: 5.1975
# 📉 Iter 9350: Val Loss = 5.8148
# [Iter 09400] ⏱ Time: 11033.2s | Avg Train Loss: 5.1937
# 📉 Iter 9400: Val Loss = 5.7985
# [Iter 09450] ⏱ Time: 11082.1s | Avg Train Loss: 5.1912
# 📉 Iter 9450: Val Loss = 5.8023
# [Iter 09500] ⏱ Time: 11135.0s | Avg Train Loss: 5.2423
# 📉 Iter 9500: Val Loss = 5.7925
# [Iter 09550] ⏱ Time: 11188.3s | Avg Train Loss: 5.1919
# 📉 Iter 9550: Val Loss = 5.7893
# [Iter 09600] ⏱ Time: 11244.9s | Avg Train Loss: 5.2025
# 📉 Iter 9600: Val Loss = 5.8201
# [Iter 09650] ⏱ Time: 11299.5s | Avg Train Loss: 5.2021
# 📉 Iter 9650: Val Loss = 5.8225
# [Iter 09700] ⏱ Time: 11350.1s | Avg Train Loss: 5.1573
# 📉 Iter 9700: Val Loss = 5.8286
# [Iter 09750] ⏱ Time: 11401.8s | Avg Train Loss: 5.2012
# 📉 Iter 9750: Val Loss = 5.8047
# [Iter 09800] ⏱ Time: 11454.7s | Avg Train Loss: 5.1799
# 📉 Iter 9800: Val Loss = 5.8020
# [Iter 09850] ⏱ Time: 11508.1s | Avg Train Loss: 5.1821
# 📉 Iter 9850: Val Loss = 5.8141
# [Iter 09900] ⏱ Time: 11564.4s | Avg Train Loss: 5.1524
# 📉 Iter 9900: Val Loss = 5.8009
# [Iter 09950] ⏱ Time: 11621.0s | Avg Train Loss: 5.1503
# 📉 Iter 9950: Val Loss = 5.8066
# [Iter 10000] ⏱ Time: 11673.5s | Avg Train Loss: 5.1559
# 📉 Iter 10000: Val Loss = 5.8184
# 📁 Training log saved to Sequence-to-Sequence model with attention.csv

# %% [markdown]
# #### Testing the Model

# %%
# Make sure model is in evaluation mode
model_attention.eval()
baseline2_preds = []

for i in range(len(test_df)):
    ingredients_baseline2 = test_df.iloc[i]['Ingredients']

    # 🔁 Join ingredients list to a string, then preprocess
    if isinstance(ingredients_baseline2, list):
        ingredients_baseline2 = " ".join(ingredients_baseline2)

    tokens_baseline2 = preprocess_text(ingredients_baseline2)
    input_ids_baseline2 = [input_vocab.get(tok, input_vocab[UNK_TOKEN]) for tok in tokens_baseline2]
    input_ids_baseline2 = input_ids_baseline2[:MAX_INGREDIENT_LEN] + [input_vocab[PAD_TOKEN]] * max(0, MAX_INGREDIENT_LEN - len(input_ids_baseline2))

    src_tensor_baseline2 = torch.tensor(input_ids_baseline2, dtype=torch.long, device=device)

    # 🧠 Generate recipe
    generated_recipe_baseline2 = generate_recipe(model_attention, src_tensor_baseline2, output_vocab, device)
    baseline2_preds.append(generated_recipe_baseline2)

# 🗂️ Add predictions to DataFrame
test_df['Recipe - Baseline 2'] = baseline2_preds

# ✅ Choose columns
columns_to_save_2 = ['Ingredients', 'Recipe - Baseline 2']
if 'Recipe' in test_df.columns:
    columns_to_save_2.insert(1, 'Recipe')

# 💾 Save to timestamped CSV
filename_2 = "baseline2_output.csv"
test_df[columns_to_save_2].to_csv(filename_2, index=False)
print(f"✅ Baseline 2 predictions saved to {filename_2}")
# Out:
# ✅ Baseline 2 predictions saved to baseline2_output.csv

# %% [markdown]
# #### Evalating the result

# %%
# Step 1: Evaluate your attention model
metrics_2 = evaluate_model(
    model_attention,
    test_loader,
    input_vocab,
    output_vocab,
    device,
    model_name="Seq2Seq-AttentionRNN"
)

# Step 2: Load existing results if the file exists
results_file = "Assignment_2_evaluation_results.csv"
if os.path.exists(results_file):
    results_df = pd.read_csv(results_file)
    results_df = pd.concat([results_df, pd.DataFrame([metrics_2])], ignore_index=True)
else:
    results_df = pd.DataFrame([metrics_2])

# Step 3: Save back to the same file
results_df.to_csv(results_file, index=False)

print(f"✅ Appended results to {results_file}")
print(results_df.tail(1))  # show just the latest entry
# Out:
# Evaluating: 100%|██████████| 1081/1081 [01:02<00:00, 17.20it/s]
# /opt/anaconda3/lib/python3.12/site-packages/transformers/tokenization_utils_base.py:1617: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be deprecated in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ✅ Appended results to Assignment_2_evaluation_results.csv
#                   Model      BLEU    METEOR  BERTScore
# 5  Seq2Seq-AttentionRNN  0.013604  0.075038   0.803288

# %% [markdown]
# ### Toy Input texts (gold and predicted recipes)

# %%
def predict_recipe_from_input(model, input_text, input_vocab, output_vocab, device,
                              preprocess_fn=preprocess_text,
                              max_input_len=MAX_INGREDIENT_LEN,
                              max_output_len=MAX_RECIPE_LEN,
                              use_attention=False):
    """
    Generate a recipe from an input ingredient list using the provided model.
    
    Args:
        model: Trained Seq2Seq model.
        input_text: Raw ingredient string.
        input_vocab: Dictionary mapping input tokens to indices.
        output_vocab: Dictionary mapping output indices to tokens.
        device: Device to run the model on (CPU or GPU).
        preprocess_fn: Preprocessing function used during training.
        max_input_len: Maximum length of input sequence.
        max_output_len: Maximum length of output recipe.
        use_attention: Whether the model uses attention.

    Returns:
        Generated recipe string.
    """
    model.eval()
    tokens = preprocess_fn(input_text)
    input_ids = [input_vocab.get(tok, input_vocab[UNK_TOKEN]) for tok in tokens]
    input_ids = input_ids[:max_input_len] + [input_vocab[PAD_TOKEN]] * max(0, max_input_len - len(input_ids))

    src_tensor = torch.tensor(input_ids, dtype=torch.long, device=device)

    with torch.no_grad():
        generated_recipe = generate_recipe(model, src_tensor, output_vocab, device,
                                           max_len=max_output_len,
                                           use_attention=use_attention)
    return generated_recipe

# %%
# Example input
user_input = "sugar, lemon juice,  water,  orange juice, strawberries, icecream"

output_recipe_attention = predict_recipe_from_input(
    model= model_attention, 
    input_text=user_input,
    input_vocab=input_vocab,
    output_vocab=output_vocab,
    device=device,
    use_attention= False # or True if the model uses attention
)
print("🧾 Generated Recipe attention:\n", output_recipe_attention)
# Out:
# 🧾 Generated Recipe baseline1:
#  mix together cream cheese sugar cream cheese sugar add milk add sugar add milk add vanilla stir well add vanilla add vanilla add vanilla beat egg white add vanilla add vanilla add vanilla beat egg white add vanilla add vanilla add vanilla beat egg white add vanilla add vanilla add vanilla beat egg white add vanilla add vanilla add
# 🧾 Generated Recipe attention:
#  mix together sugar water add sugar add vanilla add vanilla add mixture pour mixture

# %%
# Example input
user_input = "8 oz philadelphia cream cheese, 14 oz can sweetened condensed milk, 1 ts vanilla, 1/3 c  lemon juice, 48 oz canned cherries, 8 inch graham cracker,  pie crusts"

output_recipe_attention = predict_recipe_from_input(
    model= model_attention, 
    input_text=user_input,
    input_vocab=input_vocab,
    output_vocab=output_vocab,
    device=device,
    use_attention= False  # or True if the model uses attention
)
print("🧾 Generated Recipe attention:\n", output_recipe_attention)
# Out:
# 🧾 Generated Recipe baseline1:
#  mix pudding mix pudding mix well add sugar milk add sugar vanilla add vanilla beat egg white add vanilla add vanilla beat egg white add vanilla add vanilla add vanilla beat egg white add vanilla add vanilla add vanilla beat egg white add vanilla add vanilla add vanilla beat egg white add vanilla add vanilla add vanilla beat egg
# 🧾 Generated Recipe attention:
#  mix ingredient together add pineapple juice mix well pour pie crust
